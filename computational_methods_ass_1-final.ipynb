# %%
import sys
# !{sys.executable} -m pip install yfinance
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: yfinance in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (0.2.49)
# Requirement already satisfied: pandas>=1.3.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/opt/certifi/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2024.8.30)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/bin/python -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/bin/python -m pip install --upgrade pip

# %%
#Import libraries
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
mks_data = yf.download('MKS.L', start='2022-11-01', end='2024-10-31')
fres_data = yf.download('FRES.L', start='2022-11-01', end='2024-10-31')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Closing price plot for MKS
mks_figure = plt.figure()
plt.plot(mks_data['Close'])
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Closing Price (MKS.L)')
# Out:
# Text(0.5, 1.0, 'Closing Price (MKS.L)')

# %%
fres_figure = plt.figure()
plt.plot(fres_data['Close'])
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Closing Price (FRES.L)')
# Out:
# Text(0.5, 1.0, 'Closing Price (FRES.L)')

# %%
# MKS Annualised average returns

mks_adj_close_yesterday = mks_data.iloc[1:]['Adj Close'].values 
mks_adj_close_today = mks_data['Adj Close'].iloc[:-1].values
mks_daily_returns = (mks_adj_close_yesterday - mks_adj_close_today) / mks_adj_close_today
average_mks_daily_return = mks_daily_returns.mean()
mks_annualized_return = average_mks_daily_return * 252

print(mks_annualized_return)
# Out:
# 0.6601787942534045

# %%
# FRES Annualised average returns

fres_adj_close_yesterday = fres_data.iloc[1:]['Adj Close'].values 
fres_adj_close_today = fres_data['Adj Close'].iloc[:-1].values
fres_daily_returns = (fres_adj_close_yesterday - fres_adj_close_today) / fres_adj_close_today
average_fres_daily_return = fres_daily_returns.mean()
fres_annualized_return = average_fres_daily_return * 252

print(fres_annualized_return)
# Out:
# 0.0961912383642253

# %%
# MKS Annualised volatility

average_mks_daily_volatility = mks_daily_returns.std()
mks_annualized_volatility = average_mks_daily_volatility * (252 ** 0.5)

print(mks_annualized_volatility)
# Out:
# 0.2830288270860836

# %%
# FRES Annualised volatility

average_fres_daily_volatility = fres_daily_returns.std()
fres_annualized_volatility = average_fres_daily_volatility * (252 ** 0.5)

print(fres_annualized_volatility)
# Out:
# 0.3532423517104182
